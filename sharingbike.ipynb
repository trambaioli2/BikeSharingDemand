# %%
import pandas as pd
# %matplotlib inline

# %%
test = pd.read_csv("test.csv")
train = pd.read_csv("train.csv")

# %%
test.head()
# Out:
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 0  2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1  2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2  2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3  2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4  2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed
# 0        56    26.0027
# 1        56     0.0000
# 2        56     0.0000
# 3        56    11.0014
# 4        56    11.0014

# %%
train.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
train.isnull().sum()
# Out:
# datetime      0
# season        0
# holiday       0
# workingday    0
# weather       0
# temp          0
# atemp         0
# humidity      0
# windspeed     0
# casual        0
# registered    0
# count         0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# datetime      0
# season        0
# holiday       0
# workingday    0
# weather       0
# temp          0
# atemp         0
# humidity      0
# windspeed     0
# dtype: int64

# %%
train.describe()
# Out:
#              season       holiday    workingday       weather         temp  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.00000
# mean       2.506614      0.028569      0.680875      1.418427     20.23086
# std        1.116174      0.166599      0.466159      0.633839      7.79159
# min        1.000000      0.000000      0.000000      1.000000      0.82000
# 25%        2.000000      0.000000      0.000000      1.000000     13.94000
# 50%        3.000000      0.000000      1.000000      1.000000     20.50000
# 75%        4.000000      0.000000      1.000000      2.000000     26.24000
# max        4.000000      1.000000      1.000000      4.000000     41.00000
#
#               atemp      humidity     windspeed        casual    registered  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.000000
# mean      23.655084     61.886460     12.799395     36.021955    155.552177
# ...

# %%
pd.pivot_table(train, values="count", index=["holiday","season"], aggfunc="mean", margins=True)
# Out:
#                      count
# holiday season
# 0       1       117.494837
#         2       215.562756
#         3       234.293136
#         4       198.560273
# 1       1        73.929577
#         2       197.833333
#         3       237.822917
#         4       210.750000
# All             191.574132

# %%
pd.pivot_table(train, values="count", index=["workingday","season"], aggfunc="mean", margins=True)
# Out:
#                         count
# workingday season
# 0          1       105.727273
#            2       222.692857
#            3       232.520270
#            4       192.137387
# 1          1       121.326039
#            2       211.949287
#            3       235.330081
#            4       202.283857
# All                191.574132

# %%
train.corr()
# Out:
#               season   holiday  workingday   weather      temp     atemp  \
# season      1.000000  0.029368   -0.008126  0.008879  0.258689  0.264744
# holiday     0.029368  1.000000   -0.250491 -0.007074  0.000295 -0.005215
# workingday -0.008126 -0.250491    1.000000  0.033772  0.029966  0.024660
# weather     0.008879 -0.007074    0.033772  1.000000 -0.055035 -0.055376
# temp        0.258689  0.000295    0.029966 -0.055035  1.000000  0.984948
# atemp       0.264744 -0.005215    0.024660 -0.055376  0.984948  1.000000
# humidity    0.190610  0.001929   -0.010880  0.406244 -0.064949 -0.043536
# windspeed  -0.147121  0.008409    0.013373  0.007261 -0.017852 -0.057473
# casual      0.096758  0.043799   -0.319111 -0.135918  0.467097  0.462067
# registered  0.164011 -0.020956    0.119460 -0.109340  0.318571  0.314635
# count       0.163439 -0.005393    0.011594 -0.128655  0.394454  0.389784
#
#             humidity  windspeed    casual  registered     count
# ...

# %%
data = [train, test]

for i in data:
    i.loc[i["humidity"]<5,"humidity2"]=1
    i.loc[(i["humidity"]>=5) & (i["humidity"]<15),"humidity2"]=2
    i.loc[(i["humidity"]>=15) & (i["humidity"]<30),"humidity2"]=3
    i.loc[(i["humidity"]>=30) & (i["humidity"]<50),"humidity2"]=4
    i.loc[(i["humidity"]>=50) & (i["humidity"]<75),"humidity2"]=5
    i.loc[(i["humidity"]>=75) & (i["humidity"]<85),"humidity2"]=6
    i.loc[(i["humidity"]>=85) & (i["humidity"]<95),"humidity2"]=7
    i.loc[(i["humidity"]>=95) & (i["humidity"]<=100),"humidity2"]=8

# %%
pd.pivot_table(train, values="count", index=["humidity2"], aggfunc="mean", margins=True)
# Out:
#                 count
# humidity2
# 1.0         28.318182
# 2.0         44.666667
# 3.0        295.378713
# 4.0        261.140998
# 5.0        193.232828
# 6.0        136.644271
# 7.0        100.012978
# 8.0         66.506667
# All        191.574132

# %%
data = [train, test]

for i in data:
    i.loc[i["humidity"]<15,"humidity2"]=1
    i.loc[(i["humidity"]>=15) & (i["humidity"]<50),"humidity2"]=2
    i.loc[(i["humidity"]>=50) & (i["humidity"]<95),"humidity2"]=3
    i.loc[(i["humidity"]>=95) & (i["humidity"]<=100),"humidity2"]=4

# %%
pd.pivot_table(train, values="count", index=["humidity2"], aggfunc="mean", margins=True)
# Out:
#                 count
# humidity2
# 1.0         31.821429
# 2.0        265.504416
# 3.0        163.565933
# 4.0         66.506667
# All        191.574132

# %%
train.corr()
# Out:
#               season   holiday  workingday   weather      temp     atemp  \
# season      1.000000  0.029368   -0.008126  0.008879  0.258689  0.264744
# holiday     0.029368  1.000000   -0.250491 -0.007074  0.000295 -0.005215
# workingday -0.008126 -0.250491    1.000000  0.033772  0.029966  0.024660
# weather     0.008879 -0.007074    0.033772  1.000000 -0.055035 -0.055376
# temp        0.258689  0.000295    0.029966 -0.055035  1.000000  0.984948
# atemp       0.264744 -0.005215    0.024660 -0.055376  0.984948  1.000000
# humidity    0.190610  0.001929   -0.010880  0.406244 -0.064949 -0.043536
# windspeed  -0.147121  0.008409    0.013373  0.007261 -0.017852 -0.057473
# casual      0.096758  0.043799   -0.319111 -0.135918  0.467097  0.462067
# registered  0.164011 -0.020956    0.119460 -0.109340  0.318571  0.314635
# count       0.163439 -0.005393    0.011594 -0.128655  0.394454  0.389784
# humidity2   0.172060 -0.011504   -0.007567  0.282603 -0.050683 -0.025918
#
# ...

# %%
train["humidity2"].value_counts()
# Out:
# 3.0    7538
# 2.0    3170
# 4.0     150
# 1.0      28
# Name: humidity2, dtype: int64

# %%
test["humidity2"].value_counts()
# Out:
# 3.0    4671
# 2.0    1698
# 4.0     124
# Name: humidity2, dtype: int64

# %%
train["temp"].describe()
# Out:
# count    10886.00000
# mean        20.23086
# std          7.79159
# min          0.82000
# 25%         13.94000
# 50%         20.50000
# 75%         26.24000
# max         41.00000
# Name: temp, dtype: float64

# %%
train.corr()
# Out:
#               season   holiday  workingday   weather      temp     atemp  \
# season      1.000000  0.029368   -0.008126  0.008879  0.258689  0.264744
# holiday     0.029368  1.000000   -0.250491 -0.007074  0.000295 -0.005215
# workingday -0.008126 -0.250491    1.000000  0.033772  0.029966  0.024660
# weather     0.008879 -0.007074    0.033772  1.000000 -0.055035 -0.055376
# temp        0.258689  0.000295    0.029966 -0.055035  1.000000  0.984948
# atemp       0.264744 -0.005215    0.024660 -0.055376  0.984948  1.000000
# humidity    0.190610  0.001929   -0.010880  0.406244 -0.064949 -0.043536
# windspeed  -0.147121  0.008409    0.013373  0.007261 -0.017852 -0.057473
# casual      0.096758  0.043799   -0.319111 -0.135918  0.467097  0.462067
# registered  0.164011 -0.020956    0.119460 -0.109340  0.318571  0.314635
# count       0.163439 -0.005393    0.011594 -0.128655  0.394454  0.389784
# humidity2   0.172060 -0.011504   -0.007567  0.282603 -0.050683 -0.025918
#
# ...

# %%
train["count"].describe()
# Out:
# count    10886.000000
# mean       191.574132
# std        181.144454
# min          1.000000
# 25%         42.000000
# 50%        145.000000
# 75%        284.000000
# max        977.000000
# Name: count, dtype: float64

# %%
for i in data:
    i.loc[i["temp"]<5,"temp2"]=1
    i.loc[(i["temp"]>=5) & (i["temp"]<10),"temp2"]=2
    i.loc[(i["temp"]>=10) & (i["temp"]<15),"temp2"]=3
    i.loc[(i["temp"]>=15) & (i["temp"]<20),"temp2"]=4
    i.loc[(i["temp"]>=20) & (i["temp"]<25),"temp2"]=5
    i.loc[(i["temp"]>=25) & (i["temp"]<30),"temp2"]=6
    i.loc[(i["temp"]>=30) & (i["temp"]<35),"temp2"]=7
    i.loc[i["temp"]>=35,"temp2"]=8

pd.pivot_table(train, values="count", index=["temp2"], aggfunc="mean", margins=True)
# Out:
#             count
# temp2
# 1.0     53.263566
# 2.0     75.460177
# 3.0    131.797095
# 4.0    171.267885
# 5.0    209.965385
# 6.0    235.819432
# 7.0    334.538535
# 8.0    332.834197
# All    191.574132

# %%
train.corr()
# Out:
#               season   holiday  workingday   weather      temp     atemp  \
# season      1.000000  0.029368   -0.008126  0.008879  0.258689  0.264744
# holiday     0.029368  1.000000   -0.250491 -0.007074  0.000295 -0.005215
# workingday -0.008126 -0.250491    1.000000  0.033772  0.029966  0.024660
# weather     0.008879 -0.007074    0.033772  1.000000 -0.055035 -0.055376
# temp        0.258689  0.000295    0.029966 -0.055035  1.000000  0.984948
# atemp       0.264744 -0.005215    0.024660 -0.055376  0.984948  1.000000
# humidity    0.190610  0.001929   -0.010880  0.406244 -0.064949 -0.043536
# windspeed  -0.147121  0.008409    0.013373  0.007261 -0.017852 -0.057473
# casual      0.096758  0.043799   -0.319111 -0.135918  0.467097  0.462067
# registered  0.164011 -0.020956    0.119460 -0.109340  0.318571  0.314635
# count       0.163439 -0.005393    0.011594 -0.128655  0.394454  0.389784
# humidity2   0.172060 -0.011504   -0.007567  0.282603 -0.050683 -0.025918
# ...

# %%
train["windspeed"].describe()
# Out:
# count    10886.000000
# mean        12.799395
# std          8.164537
# min          0.000000
# 25%          7.001500
# 50%         12.998000
# 75%         16.997900
# max         56.996900
# Name: windspeed, dtype: float64

# %%
data = [train, test]

for i in data:
    i.loc[i["windspeed"]<10,"windspeed2"]=1
    i.loc[(i["windspeed"]>=10) & (i["windspeed"]<20),"windspeed2"]=2
    i.loc[(i["windspeed"]>=20) & (i["windspeed"]<30),"windspeed2"]=3
    i.loc[(i["windspeed"]>=30) & (i["windspeed"]<40),"windspeed2"]=4
    i.loc[(i["windspeed"]>=40) & (i["windspeed"]<50),"windspeed2"]=5
    i.loc[i["windspeed"]>=30,"windspeed2"]=6

pd.pivot_table(train, values="count", index=["windspeed2"], aggfunc="mean", margins=True)
# Out:
#                  count
# windspeed2
# 1.0         164.280710
# 2.0         210.292755
# 3.0         209.643258
# 6.0         202.257611
# All         191.574132

# %%
for i in data:
    i.loc[i["windspeed"]<10,"windspeed2"]=1
    i.loc[i["windspeed"]>=10,"windspeed2"]=2

pd.pivot_table(train, values="count", index=["windspeed2"], aggfunc="mean", margins=True)
# Out:
#                  count
# windspeed2
# 1.0         164.280710
# 2.0         209.662746
# All         191.574132

# %%
train.corr()
# Out:
#               season   holiday  workingday   weather      temp     atemp  \
# season      1.000000  0.029368   -0.008126  0.008879  0.258689  0.264744
# holiday     0.029368  1.000000   -0.250491 -0.007074  0.000295 -0.005215
# workingday -0.008126 -0.250491    1.000000  0.033772  0.029966  0.024660
# weather     0.008879 -0.007074    0.033772  1.000000 -0.055035 -0.055376
# temp        0.258689  0.000295    0.029966 -0.055035  1.000000  0.984948
# atemp       0.264744 -0.005215    0.024660 -0.055376  0.984948  1.000000
# humidity    0.190610  0.001929   -0.010880  0.406244 -0.064949 -0.043536
# windspeed  -0.147121  0.008409    0.013373  0.007261 -0.017852 -0.057473
# casual      0.096758  0.043799   -0.319111 -0.135918  0.467097  0.462067
# registered  0.164011 -0.020956    0.119460 -0.109340  0.318571  0.314635
# count       0.163439 -0.005393    0.011594 -0.128655  0.394454  0.389784
# humidity2   0.172060 -0.011504   -0.007567  0.282603 -0.050683 -0.025918
# ...

# %%
for i in data:
    i.loc[(i["holiday"]==0)&(i["workingday"]==0),"weekend"]=1

for i in data:
    i["weekend"].fillna(0, inplace=True)

pd.pivot_table(train, values="count", index=["weekend"], aggfunc="mean", margins=True)
# Out:
#               count
# weekend
# 0.0      192.724589
# 1.0      188.765096
# All      191.574132

# %%
test["weekend"].value_counts()
# Out:
# 0.0    4642
# 1.0    1851
# Name: weekend, dtype: int64

# %%
train["weekend"].value_counts()
# Out:
# 0.0    7723
# 1.0    3163
# Name: weekend, dtype: int64

# %%
train.corr()
# Out:
#               season   holiday  workingday   weather      temp     atemp  \
# season      1.000000  0.029368   -0.008126  0.008879  0.258689  0.264744
# holiday     0.029368  1.000000   -0.250491 -0.007074  0.000295 -0.005215
# workingday -0.008126 -0.250491    1.000000  0.033772  0.029966  0.024660
# weather     0.008879 -0.007074    0.033772  1.000000 -0.055035 -0.055376
# temp        0.258689  0.000295    0.029966 -0.055035  1.000000  0.984948
# atemp       0.264744 -0.005215    0.024660 -0.055376  0.984948  1.000000
# humidity    0.190610  0.001929   -0.010880  0.406244 -0.064949 -0.043536
# windspeed  -0.147121  0.008409    0.013373  0.007261 -0.017852 -0.057473
# casual      0.096758  0.043799   -0.319111 -0.135918  0.467097  0.462067
# registered  0.164011 -0.020956    0.119460 -0.109340  0.318571  0.314635
# count       0.163439 -0.005393    0.011594 -0.128655  0.394454  0.389784
# humidity2   0.172060 -0.011504   -0.007567  0.282603 -0.050683 -0.025918
# ...

# %%
train.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  humidity2  temp2  \
# 0        81        0.0       3          13     16        3.0    2.0
# 1        80        0.0       8          32     40        3.0    2.0
# 2        80        0.0       5          27     32        3.0    2.0
# 3        75        0.0       3          10     13        3.0    2.0
# 4        75        0.0       0           1      1        3.0    2.0
#
#    windspeed2  weekend  atemp2
# 0         1.0      1.0     3.0
# 1         1.0      1.0     3.0
# ...

# %%
train["atemp"].describe()
# Out:
# count    10886.000000
# mean        23.655084
# std          8.474601
# min          0.760000
# 25%         16.665000
# 50%         24.240000
# 75%         31.060000
# max         45.455000
# Name: atemp, dtype: float64

# %%
for i in data:
    i.loc[i["atemp"]<5,"atemp2"]=1
    i.loc[(i["atemp"]>=5) & (i["atemp"]<10),"atemp2"]=2
    i.loc[(i["atemp"]>=10) & (i["atemp"]<15),"atemp2"]=3
    i.loc[(i["atemp"]>=15) & (i["atemp"]<20),"atemp2"]=4
    i.loc[(i["atemp"]>=20) & (i["atemp"]<25),"atemp2"]=5
    i.loc[(i["atemp"]>=25) & (i["atemp"]<30),"atemp2"]=6
    i.loc[(i["atemp"]>=30) & (i["atemp"]<35),"atemp2"]=7
    i.loc[i["atemp"]>=35,"atemp2"]=8

pd.pivot_table(train, values="count", index=["atemp2"], aggfunc="mean", margins=True)
# Out:
#              count
# atemp2
# 1.0      49.977273
# 2.0      68.761726
# 3.0      98.376895
# 4.0     146.936842
# 5.0     175.685455
# 6.0     183.157815
# 7.0     279.132765
# 8.0     330.900889
# All     191.574132

# %%
train.corr()
# Out:
#               season   holiday  workingday   weather      temp     atemp  \
# season      1.000000  0.029368   -0.008126  0.008879  0.258689  0.264744
# holiday     0.029368  1.000000   -0.250491 -0.007074  0.000295 -0.005215
# workingday -0.008126 -0.250491    1.000000  0.033772  0.029966  0.024660
# weather     0.008879 -0.007074    0.033772  1.000000 -0.055035 -0.055376
# temp        0.258689  0.000295    0.029966 -0.055035  1.000000  0.984948
# atemp       0.264744 -0.005215    0.024660 -0.055376  0.984948  1.000000
# humidity    0.190610  0.001929   -0.010880  0.406244 -0.064949 -0.043536
# windspeed  -0.147121  0.008409    0.013373  0.007261 -0.017852 -0.057473
# casual      0.096758  0.043799   -0.319111 -0.135918  0.467097  0.462067
# registered  0.164011 -0.020956    0.119460 -0.109340  0.318571  0.314635
# count       0.163439 -0.005393    0.011594 -0.128655  0.394454  0.389784
# humidity2   0.172060 -0.011504   -0.007567  0.282603 -0.050683 -0.025918
# ...

# %%
train.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  humidity2  temp2  \
# 0        81        0.0       3          13     16        3.0    2.0
# 1        80        0.0       8          32     40        3.0    2.0
# 2        80        0.0       5          27     32        3.0    2.0
# 3        75        0.0       3          10     13        3.0    2.0
# 4        75        0.0       0           1      1        3.0    2.0
#
#    windspeed2  weekend  atemp2
# 0         1.0      1.0     3.0
# 1         1.0      1.0     3.0
# ...

# %%
lista = []
for i in train.datetime.iteritems():
    lista.append(int(i[1][11:13]))
train["hora"] = lista

lista = []
for i in train.datetime.iteritems():
    lista.append(int(i[1][8:10]))
train["dia"] = lista

lista = []
for i in train.datetime.iteritems():
    lista.append(int(i[1][5:7]))
train["mes"] = lista

# %%
train.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  humidity2  temp2  \
# 0        81        0.0       3          13     16        3.0    2.0
# 1        80        0.0       8          32     40        3.0    2.0
# 2        80        0.0       5          27     32        3.0    2.0
# 3        75        0.0       3          10     13        3.0    2.0
# 4        75        0.0       0           1      1        3.0    2.0
#
#    windspeed2  weekend  atemp2  hora  dia  mes
# 0         1.0      1.0     3.0     0    1    1
# ...

# %%
lista = []
for i in test.datetime.iteritems():
    lista.append(int(i[1][11:13]))
test["hora"] = lista

lista = []
for i in test.datetime.iteritems():
    lista.append(int(i[1][8:10]))
test["dia"] = lista

lista = []
for i in test.datetime.iteritems():
    lista.append(int(i[1][5:7]))
test["mes"] = lista

# %%
test.head()
# Out:
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 0  2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1  2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2  2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3  2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4  2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed  humidity2  temp2  windspeed2  weekend  atemp2  hora  \
# 0        56    26.0027        3.0    3.0         2.0      0.0     3.0     0
# 1        56     0.0000        3.0    3.0         1.0      0.0     3.0     1
# 2        56     0.0000        3.0    3.0         1.0      0.0     3.0     2
# 3        56    11.0014        3.0    3.0         2.0      0.0     3.0     3
# 4        56    11.0014        3.0    3.0         2.0      0.0     3.0     4
#
#    dia  mes
# 0   20    1
# 1   20    1
# ...

# %%
pd.pivot_table(train, values="count", index=["hora"], aggfunc="mean", margins=True)
# Out:
#            count
# hora
# 0      55.138462
# 1      33.859031
# 2      22.899554
# 3      11.757506
# 4       6.407240
# 5      19.767699
# 6      76.259341
# 7     213.116484
# 8     362.769231
# 9     221.780220
# 10    175.092308
# 11    210.674725
# 12    256.508772
# 13    257.787281
# 14    243.442982
# 15    254.298246
# 16    316.372807
# 17    468.765351
# 18    430.859649
# 19    315.278509
# 20    228.517544
# 21    173.370614
# 22    133.576754
# 23     89.508772
# All   191.574132

# %%
train.corr()
# Out:
#               season   holiday  workingday   weather      temp     atemp  \
# season      1.000000  0.029368   -0.008126  0.008879  0.258689  0.264744
# holiday     0.029368  1.000000   -0.250491 -0.007074  0.000295 -0.005215
# workingday -0.008126 -0.250491    1.000000  0.033772  0.029966  0.024660
# weather     0.008879 -0.007074    0.033772  1.000000 -0.055035 -0.055376
# temp        0.258689  0.000295    0.029966 -0.055035  1.000000  0.984948
# atemp       0.264744 -0.005215    0.024660 -0.055376  0.984948  1.000000
# humidity    0.190610  0.001929   -0.010880  0.406244 -0.064949 -0.043536
# windspeed  -0.147121  0.008409    0.013373  0.007261 -0.017852 -0.057473
# casual      0.096758  0.043799   -0.319111 -0.135918  0.467097  0.462067
# registered  0.164011 -0.020956    0.119460 -0.109340  0.318571  0.314635
# count       0.163439 -0.005393    0.011594 -0.128655  0.394454  0.389784
# humidity2   0.172060 -0.011504   -0.007567  0.282603 -0.050683 -0.025918
# ...

# %%
train.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  humidity2  temp2  \
# 0        81        0.0       3          13     16        3.0    2.0
# 1        80        0.0       8          32     40        3.0    2.0
# 2        80        0.0       5          27     32        3.0    2.0
# 3        75        0.0       3          10     13        3.0    2.0
# 4        75        0.0       0           1      1        3.0    2.0
#
#    windspeed2  weekend  atemp2  hora
# 0         1.0      1.0     3.0     0
# ...

# %%
data = [train, test]

for i in data:
    i["windspeed2"] = i["windspeed2"].astype(int)
    i["weekend"] = i["weekend"].astype(int)
    i["temp2"] = i["temp2"].astype(int)
    i["atemp2"] = i["atemp2"].astype(int)
    i["humidity2"] = i["humidity2"].astype(int)
    i["temp"] = i["temp"].astype(int)
    i["atemp"] = i["atemp"].astype(int)
    i["humidity"] = i["humidity"].astype(int)
    i["windspeed"] = i["windspeed"].astype(int)

# %%
train.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp  atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1     9     14
# 1  2011-01-01 01:00:00       1        0           0        1     9     13
# 2  2011-01-01 02:00:00       1        0           0        1     9     13
# 3  2011-01-01 03:00:00       1        0           0        1     9     14
# 4  2011-01-01 04:00:00       1        0           0        1     9     14
#
#    humidity  windspeed  casual  registered  count  humidity2  temp2  \
# 0        81          0       3          13     16          3      2
# 1        80          0       8          32     40          3      2
# 2        80          0       5          27     32          3      2
# 3        75          0       3          10     13          3      2
# 4        75          0       0           1      1          3      2
#
#    windspeed2  weekend  atemp2  hora  dia  mes
# 0           1        1       3     0    1    1
# ...

# %%
dropa = ['datetime','temp2','atemp','windspeed','humidity']
train2 = train.drop(dropa, axis=1)
test2 = test.drop(dropa, axis=1)

# %%
train2.head()
# Out:
#    season  holiday  workingday  weather  casual  registered  count  humidity2  \
# 0       1        0           0        1       3          13     16          3
# 1       1        0           0        1       8          32     40          3
# 2       1        0           0        1       5          27     32          3
# 3       1        0           0        1       3          10     13          3
# 4       1        0           0        1       0           1      1          3
#
#    temp2  windspeed2  weekend  atemp2  hora  dia  mes
# 0      2           1        1       3     0    1    1
# 1      2           1        1       3     1    1    1
# 2      2           1        1       3     2    1    1
# 3      2           1        1       3     3    1    1
# 4      2           1        1       3     4    1    1

# %%
X_train = train2.drop(['casual','registered','count'], axis=1)
y_train = train2['count']
X_test = test2.drop(['count'], axis=1)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf = DecisionTreeClassifier()
clf.fit(X_train,y_train)
y_pred_DTC = clf.predict(X_test)
acc_DTC = round (clf.score(X_train,y_train)*100,2)
print(str(acc_DTC) + " porcentagem")
# Out:
# 98.53 porcentagem

# %%
test2["count"] = y_pred_DTC

# %%
test["count"] = test2["count"]

# %%
test.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp  atemp  \
# 0  2011-01-20 00:00:00       1        0           1        1    10     11
# 1  2011-01-20 01:00:00       1        0           1        1    10     13
# 2  2011-01-20 02:00:00       1        0           1        1    10     13
# 3  2011-01-20 03:00:00       1        0           1        1    10     12
# 4  2011-01-20 04:00:00       1        0           1        1    10     12
#
#    humidity  windspeed  humidity2  temp2  windspeed2  weekend  atemp2  hora  \
# 0        56         26          3      3           2        0       3     0
# 1        56          0          3      3           1        0       3     1
# 2        56          0          3      3           1        0       3     2
# 3        56         11          3      3           2        0       3     3
# 4        56         11          3      3           2        0       3     4
#
#    dia  mes  count
# 0   20    1      3
# 1   20    1      5
# ...

# %%
x = test.drop(["dia","mes","season",'holiday','workingday','weather','temp','atemp','humidity','windspeed','temp2','windspeed2','weekend','atemp2','hora','humidity2'],axis=1)
x.head()
# Out:
#               datetime  count
# 0  2011-01-20 00:00:00      3
# 1  2011-01-20 01:00:00      5
# 2  2011-01-20 02:00:00     12
# 3  2011-01-20 03:00:00      4
# 4  2011-01-20 04:00:00      1

# %%
x.set_index("datetime", inplace=True)
x.to_csv("resultado4.csv")

# %% [markdown]
# #Testando com o count sendo gerado a partir da geração do casual e registered

# %%
X_train = train2.drop(['casual','registered','count'], axis=1)
y_train = train2['casual']
X_test = test2.drop(['count'], axis=1)

# %%
clf = DecisionTreeClassifier()
clf.fit(X_train,y_train)
y_pred_DTC = clf.predict(X_test)
acc_DTC = round (clf.score(X_train,y_train)*100,2)
print(str(acc_DTC) + " porcentagem")
# Out:
# 98.63 porcentagem

# %%
test2["casual"] = y_pred_DTC

# %%
X_train = train2.drop(['casual','registered','count'], axis=1)
y_train = train2['registered']
X_test = test2.drop(['casual', 'count'], axis=1)

# %%
clf = DecisionTreeClassifier()
clf.fit(X_train,y_train)
y_pred_DTC = clf.predict(X_test)
acc_DTC = round (clf.score(X_train,y_train)*100,2)
print(str(acc_DTC) + " porcentagem")
# Out:
# 98.56 porcentagem

# %%
test2["registered"] = y_pred_DTC

# %%
lista = []
lista2 = []
lista3 = []
for i in test2.casual.iteritems():
    lista.append(i[1])
lista3.append(lista)
    
for i in test2.registered.iteritems():
    lista2.append(i[1])

lista3.append(lista2)

# %%
lista = []
for i in range(len(lista3[0])):
    x = lista3[0][i] + lista3[1][i]
    lista.append(x)

test2["count"]=lista2

# %%
test["count"] = test2["count"]

# %%
x = test.drop(["dia","mes","season",'holiday','workingday','weather','temp','atemp','humidity','windspeed','temp2','windspeed2','weekend','atemp2','hora','humidity2'],axis=1)
x.head()
# Out:
#               datetime  count
# 0  2011-01-20 00:00:00     16
# 1  2011-01-20 01:00:00     16
# 2  2011-01-20 02:00:00      5
# 3  2011-01-20 03:00:00      1
# 4  2011-01-20 04:00:00      1

# %%
x.set_index("datetime", inplace=True)
x.to_csv("resultado4.csv")

# %% [markdown]
# #Submissão pela obtenção do count diretamente obteve melhor resultado
